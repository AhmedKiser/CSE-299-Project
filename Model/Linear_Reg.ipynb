# %%
#import lib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('Crop_recommendation.csv')

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
X=df.drop( ['temperature','humidity','rainfall','label'],axis=1)

# %%
y=df['label']

# %%
X
# Out:
#         N   P   K        ph
# 0      90  42  43  6.502985
# 1      85  58  41  7.038096
# 2      60  55  44  7.840207
# 3      74  35  40  6.980401
# 4      78  42  42  7.628473
# ...   ...  ..  ..       ...
# 2195  107  34  32  6.780064
# 2196   99  15  27  6.086922
# 2197  118  33  30  6.362608
# 2198  117  32  34  6.758793
# 2199  104  18  30  6.779833
#
# [2200 rows x 4 columns]

# %%
y
# Out:
# 0         rice
# 1         rice
# 2         rice
# 3         rice
# 4         rice
#          ...
# 2195    coffee
# 2196    coffee
# 2197    coffee
# 2198    coffee
# 2199    coffee
# Name: label, Length: 2200, dtype: object

# %%
xdf = df.copy()
xdf
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder 
labelencoder= LabelEncoder()

# %%
xdf['label_codes'] = labelencoder.fit_transform(xdf['label']) 
xdf
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label  \
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
#       label_codes
# 0              20
# 1              20
# 2              20
# 3              20
# 4              20
# ...           ...
# 2195            5
# 2196            5
# 2197            5
# 2198            5
# 2199            5
#
# [2200 rows x 9 columns]

# %%
X = xdf.drop(['temperature','humidity','rainfall','label','label_codes'],axis = 1)

# %%
y = xdf['label_codes']

# %%
X
# Out:
#         N   P   K        ph
# 0      90  42  43  6.502985
# 1      85  58  41  7.038096
# 2      60  55  44  7.840207
# 3      74  35  40  6.980401
# 4      78  42  42  7.628473
# ...   ...  ..  ..       ...
# 2195  107  34  32  6.780064
# 2196   99  15  27  6.086922
# 2197  118  33  30  6.362608
# 2198  117  32  34  6.758793
# 2199  104  18  30  6.779833
#
# [2200 rows x 4 columns]

# %%
y
# Out:
# 0       20
# 1       20
# 2       20
# 3       20
# 4       20
#         ..
# 2195     5
# 2196     5
# 2197     5
# 2198     5
# 2199     5
# Name: label_codes, Length: 2200, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(Xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ytest
# Out:
# 1456    15
# 1187    12
# 941     19
# 439     18
# 1481    15
#         ..
# 1149    12
# 575     13
# 1551     0
# 1388    21
# 186     11
# Name: label_codes, Length: 660, dtype: int64

# %%
pred=reg.predict(Xtest)

# %%
pred
# Out:
# array([13.50006764, 13.26403437, 14.90585338, 10.61779427, 12.79790634,
#         8.07379002, 11.59009633,  9.66947395, 10.43606713, 15.61508048,
#        10.61168316,  8.31296382, 10.87503114,  2.94181382,  2.68306391,
#        12.2840273 , 12.7016996 , 10.58830554,  4.58669067, 12.19376474,
#        15.79844015, 10.08552204,  3.95152274, 16.58207666,  4.63475556,
#         7.9074821 , 11.00273064, 11.34008883,  9.30446357,  2.07784034,
#         2.654244  ,  8.38829178, 10.60677223,  2.30841696, 11.83786489,
#        13.85332371,  9.83282665, 15.99983525, 10.03525134,  9.35255932,
#        13.69494004, 10.29850126,  6.56515036,  4.97719307,  9.78737866,
#         7.61130152,  9.78563415, 13.24590667,  7.97952041,  8.01562235,
#        10.98773179,  9.86181071, 10.48110503,  6.4292536 , 12.0790976 ,
#         8.29225715,  9.34888967,  9.25896445,  3.6556869 , 14.32496905,
#        14.01614161, 14.16395302, 13.47178847, 10.84570821,  8.62570116,
#         9.25158802,  2.26351621, 11.6680444 , 11.11709149, 12.00615717,
#        10.72937283, 11.47273192,  6.0765178 ,  9.30591624, 11.03733065,
#         4.80810325,  8.84846382, 10.19230354, 15.79042581, 11.66755556,
#        10.29782261, 11.59418673,  2.74317515,  9.87547067,  8.83118389,
#        10.61338451, 12.16939652, 14.19075409,  7.34375958,  8.31382688,
#        10.03422846, 16.05991772,  8.97963639,  9.14385252,  5.29957192,
#         8.56968025,  9.63798645, 10.72751806, 14.31984982, 10.82627269,
#        13.87323651, 10.17397306,  2.83632003,  2.27902202, 13.29509103,
#        14.23661539, 15.34265251, 16.84488611, 16.73058107,  9.50246217,
#        11.75483615, 13.48665308, 11.70444644, 14.75624268, 10.87117337,
#        14.35151156, 12.98214212, 10.0582165 , 11.98237852, 11.56127114,
#         5.46336364, 12.65905014,  5.60722798, 15.37487305, 11.931762  ,
#        16.29488523, 10.04811802,  5.09001987, 17.10403571,  9.9655135 ,
#        12.33233812, 10.70188777,  3.42298145, 12.67666007, 11.17592719,
#        11.30509297,  3.20585518,  9.32488053,  5.80090935, 16.37318484,
#        11.93891521, 11.64160487, 14.054119  , 11.23326962, 14.94829344,
#         9.78321491, 11.0423349 ,  9.98395241, 10.13367065, 11.16078688,
#         9.43741276,  4.67903606,  9.41308221,  7.75626905, 14.54722537,
#        11.75135727,  9.93617829, 16.2732392 ,  9.61966985, 10.4804507 ,
#         3.01444049, 15.84055355,  5.95829891,  9.09914452, 13.69696054,
#         9.22716647, 10.47173083, 13.9965459 , 12.81578066, 10.45076397,
#         8.88421136, 12.04039274,  9.9175393 ,  2.90190978, 16.14812966,
#        14.63520233, 11.18761345, 12.37614898,  2.51601409, 12.26502791,
#        10.2022163 , 12.10619631,  9.9052239 ,  3.20706924, 13.42537128,
#         5.1876991 , 10.59252307, 11.08402026,  9.23416675, 12.51253197,
#         4.22626641, 10.70680811,  9.08442197, 11.39702877,  9.77468134,
#         8.94466644, 14.37276149, 15.60408821, 11.21041133, 11.83005233,
#         5.237021  ,  9.5314613 , 10.23451338, 12.09009906,  1.86745115,
#         2.22488447,  2.35410041, 10.47054505, 10.15866562, 11.41395264,
#        11.23254229,  6.7353386 , 14.25700599, 12.16341903, 11.27178777,
#        15.55098921, 11.34767738,  3.00298229, 12.43714384,  9.24222676])

# %%
from sklearn.metrics import mean_squared_error

# %%
accuracy_train = []
accuracy_test = []
model_name = []

# %%
predict_linear_train = reg.predict(Xtrain)
MSE_linear_train = ( mean_squared_error(ytrain, predict_linear_train)  )

accuracy_linear_train = 100 - MSE_linear_train
print("Train Accuracy: ", accuracy_linear_train)
# Out:
# Train Accuracy:  70.79354307591709

# %%
predict_linear_test = reg.predict(Xtest)
MSE_linear_test = ( mean_squared_error(ytest, predict_linear_test)  )
accuracy_linear_test = 100 - MSE_linear_test
print("Test Accuracy: ", accuracy_linear_test)

accuracy_train.append( accuracy_linear_train )
accuracy_test.append( accuracy_linear_test )
model_name.append('Linear Regression')
# Out:
# Test Accuracy:  69.94499006820541

# %%
dftable = pd.DataFrame(columns={'accuracy_train', 'accuracy_test', 'model_name'})
dftable['accuracy_train'] = accuracy_train
dftable['accuracy_test'] = accuracy_test
dftable['model_name'] = model_name
dftable = dftable[['model_name', 'accuracy_train', 'accuracy_test']]
dftable
# Out:
#           model_name  accuracy_train  accuracy_test
# 0  Linear Regression       70.793543       69.94499
