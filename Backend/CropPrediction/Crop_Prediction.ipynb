# %%
#import Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # New section

# %%
df = pd.read_csv('/content/Crop_recommendation - Crop_recommendation.csv')

# %%
df
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
df.head(10)
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice
# 5  69  37  42    23.058049  83.370118  7.073454  251.055000  rice
# 6  69  55  38    22.708838  82.639414  5.700806  271.324860  rice
# 7  94  53  40    20.277744  82.894086  5.718627  241.974195  rice
# 8  89  54  38    24.515881  83.535216  6.685346  230.446236  rice
# 9  68  58  38    23.223974  83.033227  6.336254  221.209196  rice

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.isnull().any()
# Out:
# N              False
# P              False
# K              False
# temperature    False
# humidity       False
# ph             False
# rainfall       False
# label          False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
a = df[['N']]
b = df[['P']]
c = df[['K']]
d = df[['temperature']]
e = df[['humidity']]
f = df[['rainfall']]
y = df['label']

# %%
a,b,c,d,e,f,y
# Out:
# (        N
#  0      90
#  1      85
#  2      60
#  3      74
#  4      78
#  ...   ...
#  2195  107
#  2196   99
#  2197  118
#  2198  117
#  2199  104
#
#  [2200 rows x 1 columns],        P
#  0     42
#  1     58
#  2     55
#  3     35
#  4     42
#  ...   ..
#  2195  34
#  2196  15
#  2197  33
#  2198  32
#  2199  18
#
#  [2200 rows x 1 columns],        K
#  0     43
#  1     41
#  2     44
#  3     40
#  4     42
#  ...   ..
#  2195  32
#  2196  27
#  2197  30
#  2198  34
#  2199  30
#
#  [2200 rows x 1 columns],       temperature
#  0       20.879744
#  1       21.770462
#  2       23.004459
#  3       26.491096
#  4       20.130175
#  ...           ...
#  2195    26.774637
#  2196    27.417112
#  2197    24.131797
#  2198    26.272418
#  2199    23.603016
#
#  [2200 rows x 1 columns],        humidity
#  0     82.002744
#  1     80.319644
#  2     82.320763
#  3     80.158363
#  4     81.604873
#  ...         ...
#  2195  66.413269
#  2196  56.636362
#  2197  67.225123
# ...

# %%
plt.plot(a)
plt.show()

# %%
plt.plot(b)
plt.show()

# %%
plt.plot(c)
plt.show()

# %%
plt.plot(d)
plt.show()

# %%
plt.plot(e)
plt.show()

# %%
plt.plot(f)
plt.show()

# %%
plt.plot(y)
plt.show()

# %%
plt.plot(a)
plt.show()

# %%
plt.plot(b)
plt.show()

# %%
plt.plot(c)
plt.show()

# %%
plt.plot(d)
plt.show()

# %%
plt.plot(e)
plt.show()

# %%
plt.plot(f)
plt.show()

# %%
plt.plot(y)
plt.show()

# %%
plt.plot(a, marker = 'o')
plt.show()

# %%
plt.plot(b, marker = 'o')
plt.show()

# %%
plt.plot(c, marker = 'o')
plt.show()

# %%
plt.plot(d, marker = 'o')
plt.show()

# %%
plt.plot(e, marker = 'o')
plt.show()

# %%
plt.plot(f, marker = 'o')
plt.show()

# %%
plt.plot(y, marker = 'o')
plt.show()

# %%
plt.plot(a, linestyle = 'dotted')
plt.show()

# %%
plt.plot(b, linestyle = 'dotted')
plt.show()

# %%
plt.plot(c, linestyle = 'dotted')
plt.show()

# %%
plt.plot(d, linestyle = 'dotted')
plt.show()

# %%
plt.plot(e, linestyle = 'dotted')
plt.show()

# %%
plt.plot(f, linestyle = 'dotted')
plt.show()

# %%
plt.plot(y, linestyle = 'dotted')
plt.show()

# %%
plt.plot(a)

plt.xlabel("total")
plt.ylabel("N")

plt.show()

# %%
plt.plot(b)

plt.xlabel("P")
plt.ylabel("total")

plt.show()

# %%
plt.plot(c)

plt.xlabel("total")
plt.ylabel("k")

plt.show()

# %%
plt.plot(d)

plt.xlabel("total")
plt.ylabel("temperature")

plt.show()

# %%
plt.plot(e)

plt.xlabel("total")
plt.ylabel("humidity")

plt.show()

# %%
plt.plot(f)

plt.xlabel("total")
plt.ylabel("rainfall")

plt.show()

# %%
plt.plot(y)

plt.xlabel("total")
plt.ylabel("label")

plt.show()

# %%
plt.title("Nitrogen vs Total")
plt.xlabel("Total")
plt.ylabel("N")

plt.plot(a)

plt.grid()

plt.show()

# %%
plt.title("Phosphorus vs Total")
plt.xlabel("Total")
plt.ylabel("P")

plt.plot(b)

plt.grid()

plt.show()

# %%
plt.title("potassium  vs Total")
plt.xlabel("Total")
plt.ylabel("K")

plt.plot(c)

plt.grid()

plt.show()

# %%
plt.title("Temperature vs Total")
plt.xlabel("Total")
plt.ylabel("Temperature")

plt.plot(d)

plt.grid()

plt.show()

# %%
plt.title("Humidity vs Total")
plt.xlabel("Total")
plt.ylabel("Humidity")

plt.plot(e)

plt.grid()

plt.show()

# %%
plt.title("Rainfall vs Total")
plt.xlabel("Total")
plt.ylabel("Rainfall")

plt.plot(f)

plt.grid()

plt.show()

# %%
plt.title("Total")
plt.xlabel("Total")
plt.ylabel("Label")

plt.plot(y)

plt.grid()

plt.show()

# %%
plt.scatter(a,y)
plt.show()

# %%
plt.scatter(b, y)
plt.show()

# %%
plt.scatter(c, y)
plt.show()

# %%
plt.scatter(d, y)
plt.show()

# %%
plt.scatter(e, y)
plt.show()

# %%
plt.scatter(f, y)
plt.show()

# %%
plt.scatter(y, y)
plt.show()

# %%
plt.bar(a.index,y.values.reshape(len(y)))
plt.show()

# %%
plt.bar(b.index,y.values.reshape(len(y)))
plt.show()

# %%
plt.bar(c.index,y.values.reshape(len(y)))
plt.show()

# %%
plt.bar(d.index,y.values.reshape(len(y)))
plt.show()

# %%
plt.bar(e.index,y.values.reshape(len(y)))
plt.show()

# %%
plt.bar(f.index,y.values.reshape(len(y)))
plt.show()

# %%
plt.bar(y.index,y.values.reshape(len(y)))
plt.show()
